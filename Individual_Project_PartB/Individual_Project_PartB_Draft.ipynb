# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikreddy2299/Karthikreddy_Data690/blob/main/Individual_Project_PartB/Individual_Project_PartB_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Individual Project - Part B (Draft)
#
#
# Name: Karthik Reddy
#
# Date: 04/02/2022

# %% [markdown]
# ## Indicator Profile:
#
# ### Education.
#
# ### Abstract:
#
# - Education means studying in order to obtain a deeper knowledge and understanding of a variety of subjects to be applied to daily life. Education is not limited to just knowledge from books, but can also be obtained through practical experiences outside of the classroom.
# - In order for the entire world to really become equal, it needs to start with education. If everyone was provided with the same opportunities to education, then there would be less gaps between social classes.
# - More than 260 million children worldwide are out of school, yet more than half of those in education are not learning, the "World Bank has warned".
# - In today’s society, having an education is considered a vital part of being accepted by those around you. Having an education is believed to make you a useful part of society, and can make you feel like a contributing member as well.
#
# ### Global education facts:
#
# - In 39 out of 99 countries, fewer than 50% of the poorest children have completed primary school. In some countries like South Sudan, that figure is as low as 7%.
# - More than 50% of young people in 58 out of 133 countries have not completed upper secondary school. In Niger, only 2% of its young people have completed this education.
# - In 35 out of 75 countries, at least 25% of the poorest young women are illiterate.
# - In 30 countries, fewer than 90 females for every 100 males complete lower-secondary school.
#
# ## Indicator Topics:
# - Population ages 15-64(% of total population).
# - Literacy rate, youth total(% of people ages 15-24).
# - Government expenditure on education, total(% of government expenditure).
# - Unemployment, total(% of total labor force).
# - Population, ages 15-24, total.
# - Coverage: Finished primary school.
#
# **Countries:**
# - Burkina Faso.
# - Ethiopia.
# - Liberia.
# - Madagascar.
# - Uganda.
# - Central African Republic.
# - Togo.
#
# **Time Plot Years:**
# - 2012 - 2020.

# %%
import pandas as pd
import plotly
import plotly.express as px

DATA = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/Karthikreddy_Data690/main/Individual_Project_PartB/wdi_data.csv"
DATA = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/Karthikreddy_Data690/main/Individual_Project_PartB/wdi_data%20(1).csv"
DATA = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/Karthikreddy_Data690/main/Individual_Project_PartB/wdi_data%20(2).csv"

# %%
df = pd.read_csv(DATA)

df.sample(15)
# Out:
#      Unnamed: 0  Year         value          indicator Country Code  \
# 203         203  2017  2.314004e+01  SE.XPD.TOTL.GB.ZS          TGO
# 156         156  2015  4.945440e+06  SP.POP.1524.TO.UN          MDG
# 192         192  2015  1.696291e+01  SE.XPD.TOTL.GB.ZS          MDG
# 27           27  2012  2.170000e+00     SL.UEM.TOTL.ZS          LBR
# 114         114  2016  5.582712e+01  SP.POP.1564.TO.ZS          MDG
# 83           83  2012  5.229940e+01  SP.POP.1564.TO.ZS          CAF
# 53           53  2020  3.945000e+00     SL.UEM.TOTL.ZS          TGO
# 111         111  2013  5.476325e+01  SP.POP.1564.TO.ZS          MDG
# 4             4  2016  4.434000e+00     SL.UEM.TOTL.ZS          BFA
# 164         164  2015  8.244246e+06  SP.POP.1524.TO.UN          UGA
# 202         202  2016  1.599131e+01  SE.XPD.TOTL.GB.ZS          TGO
# 207         207  2014  1.170491e+01  SE.XPD.TOTL.GB.ZS          UGA
# 117         117  2019  5.658910e+01  SP.POP.1564.TO.ZS          MDG
# 176         176  2020  9.782440e+00  SE.XPD.TOTL.GB.ZS          CAF
# 12           12  2015  5.606000e+00     SL.UEM.TOTL.ZS          CAF
#
#                  Country Name               Region Income Group Lending Type
# 203                      Togo  Sub-Saharan Africa    Low income          IDA
# 156                Madagascar  Sub-Saharan Africa    Low income          IDA
# 192                Madagascar  Sub-Saharan Africa    Low income          IDA
# 27                    Liberia  Sub-Saharan Africa    Low income          IDA
# 114                Madagascar  Sub-Saharan Africa    Low income          IDA
# 83   Central African Republic  Sub-Saharan Africa    Low income          IDA
# 53                       Togo  Sub-Saharan Africa    Low income          IDA
# 111                Madagascar  Sub-Saharan Africa    Low income          IDA
# 4                Burkina Faso  Sub-Saharan Africa    Low income          IDA
# 164                    Uganda  Sub-Saharan Africa    Low income          IDA
# 202                      Togo  Sub-Saharan Africa    Low income          IDA
# 207                    Uganda  Sub-Saharan Africa    Low income          IDA
# 117                Madagascar  Sub-Saharan Africa    Low income          IDA
# 176  Central African Republic  Sub-Saharan Africa    Low income          IDA
# 12   Central African Republic  Sub-Saharan Africa    Low income          IDA

# %%
df['Country Name'].unique()
# Out:
# array(['Burkina Faso', 'Central African Republic', 'Ethiopia', 'Liberia',
#        'Madagascar', 'Togo', 'Uganda'], dtype=object)

# %%
df['Country Code'].unique()
# Out:
# array(['BFA', 'CAF', 'ETH', 'LBR', 'MDG', 'TGO', 'UGA'], dtype=object)

# %%
df_2019_pop_age.head(20)
# Out:
#      Unnamed: 0  Year      value          indicator Country Code  \
# 74           74  2012  51.467297  SP.POP.1564.TO.ZS          BFA
# 83           83  2012  52.299401  SP.POP.1564.TO.ZS          CAF
# 92           92  2012  52.770910  SP.POP.1564.TO.ZS          ETH
# 101         101  2012  53.884061  SP.POP.1564.TO.ZS          LBR
# 110         110  2012  54.352105  SP.POP.1564.TO.ZS          MDG
# 119         119  2012  54.569844  SP.POP.1564.TO.ZS          TGO
# 128         128  2012  49.388649  SP.POP.1564.TO.ZS          UGA
#
#                  Country Name               Region Income Group Lending Type
# 74               Burkina Faso  Sub-Saharan Africa    Low income          IDA
# 83   Central African Republic  Sub-Saharan Africa    Low income          IDA
# 92                   Ethiopia  Sub-Saharan Africa    Low income          IDA
# 101                   Liberia  Sub-Saharan Africa    Low income          IDA
# 110                Madagascar  Sub-Saharan Africa    Low income          IDA
# 119                      Togo  Sub-Saharan Africa    Low income          IDA
# 128                    Uganda  Sub-Saharan Africa    Low income          IDA

# %%
df_2019_pop_age = df.query("Year == 2012").query("indicator == 'SP.POP.1564.TO.ZS'")
df_2019_pop_age
# Out:
#      Unnamed: 0  Year      value          indicator Country Code  \
# 74           74  2012  51.467297  SP.POP.1564.TO.ZS          BFA
# 83           83  2012  52.299401  SP.POP.1564.TO.ZS          CAF
# 92           92  2012  52.770910  SP.POP.1564.TO.ZS          ETH
# 101         101  2012  53.884061  SP.POP.1564.TO.ZS          LBR
# 110         110  2012  54.352105  SP.POP.1564.TO.ZS          MDG
# 119         119  2012  54.569844  SP.POP.1564.TO.ZS          TGO
# 128         128  2012  49.388649  SP.POP.1564.TO.ZS          UGA
#
#                  Country Name               Region Income Group Lending Type
# 74               Burkina Faso  Sub-Saharan Africa    Low income          IDA
# 83   Central African Republic  Sub-Saharan Africa    Low income          IDA
# 92                   Ethiopia  Sub-Saharan Africa    Low income          IDA
# 101                   Liberia  Sub-Saharan Africa    Low income          IDA
# 110                Madagascar  Sub-Saharan Africa    Low income          IDA
# 119                      Togo  Sub-Saharan Africa    Low income          IDA
# 128                    Uganda  Sub-Saharan Africa    Low income          IDA

# %%
df_uga = [df_2019_pop_age['Country Code']== 'UGA']
df_uga
# Out:
# [74     False
#  83     False
#  92     False
#  101    False
#  110    False
#  119    False
#  128     True
#  Name: Country Code, dtype: bool]

# %%
df_caf = df_2019_pop_age[df_2019_pop_age['Country Code']== 'CAF']
df_caf
# Out:
#     Unnamed: 0  Year      value          indicator Country Code  \
# 83          83  2012  52.299401  SP.POP.1564.TO.ZS          CAF
#
#                 Country Name               Region Income Group Lending Type
# 83  Central African Republic  Sub-Saharan Africa    Low income          IDA

# %%
fig = px.bar(
   df_2019_pop_age, 
    x="Country Name", 
    labels={"value":"2012 Bar Plot of all countries Population Ages", "Country Name":""},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a472d6b9-064e-4d7e-b741-d41f7c26571d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a472d6b9-064e-4d7e-b741-d41f7c26571d")) {                    Plotly.newPlot(                        "a472d6b9-064e-4d7e-b741-d41f7c26571d",                        [{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Burkina Faso","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Burkina Faso","offsetgroup":"Burkina Faso","orientation":"v","showlegend":true,"textposition":"auto","x":["Burkina Faso"],"xaxis":"x","y":[51.4672970113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Central African Republic","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Central African Republic","offsetgroup":"Central African Republic","orientation":"v","showlegend":true,"textposition":"auto","x":["Central African Republic"],"xaxis":"x","y":[52.2994011382],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Ethiopia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ethiopia","offsetgroup":"Ethiopia","orientation":"v","showlegend":true,"textposition":"auto","x":["Ethiopia"],"xaxis":"x","y":[52.7709102156],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Liberia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Liberia","offsetgroup":"Liberia","orientation":"v","showlegend":true,"textposition":"auto","x":["Liberia"],"xaxis":"x","y":[53.8840605572],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Madagascar","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Madagascar","offsetgroup":"Madagascar","orientation":"v","showlegend":true,"textposition":"auto","x":["Madagascar"],"xaxis":"x","y":[54.3521052042],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Togo","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Togo","offsetgroup":"Togo","orientation":"v","showlegend":true,"textposition":"auto","x":["Togo"],"xaxis":"x","y":[54.5698439386],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2012 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Uganda","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Uganda","offsetgroup":"Uganda","orientation":"v","showlegend":true,"textposition":"auto","x":["Uganda"],"xaxis":"x","y":[49.3886489493],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorba ...

# %%
df_lit_rate = df.query("indicator == 'SE.ADT.1524.LT.ZS'")
df_lit_rate = df_lit_rate[df_lit_rate["Country Code"].isin(["BFA","CAF","UGA", "ETH","LBR","TGO","MGD"])]

fig = px.line(
    df_lit_rate, 
    x="Year", 
    labels={"value":"Literacy Rate Youth Total"},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[7],
    title="Literacy rate, youth total(% of people ages 15-24)"

)


fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6fae3b76-fe9d-45c9-aee5-726aba816fff" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fae3b76-fe9d-45c9-aee5-726aba816fff")) {                    Plotly.newPlot(                        "6fae3b76-fe9d-45c9-aee5-726aba816fff",                        [{"hovertemplate":"Country Name=Burkina Faso<br>Year=%{x}<br>Literacy Rate Youth Total=%{y}<extra></extra>","legendgroup":"Burkina Faso","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Burkina Faso","orientation":"v","showlegend":true,"x":[2014,2018],"xaxis":"x","y":[50.0962982178,58.8739814758],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Central African Republic<br>Year=%{x}<br>Literacy Rate Youth Total=%{y}<extra></extra>","legendgroup":"Central African Republic","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Central African Republic","orientation":"v","showlegend":true,"x":[2018],"xaxis":"x","y":[38.2686500549],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Ethiopia<br>Year=%{x}<br>Literacy Rate Youth Total=%{y}<extra></extra>","legendgroup":"Ethiopia","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ethiopia","orientation":"v","showlegend":true,"x":[2017],"xaxis":"x","y":[72.7548217773],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Liberia<br>Year=%{x}<br>Literacy Rate Youth Total=%{y}<extra></extra>","legendgroup":"Liberia","line":{"color":"#D62728","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Liberia","orientation":"v","showlegend":true,"x":[2017],"xaxis":"x","y":[55.3987007141],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Togo<br>Year=%{x}<br>Literacy Rate Youth Total=%{y}<extra></extra>","legendgroup":"Togo","line":{"color":"#9467BD","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Togo","orientation":"v","showlegend":true,"x":[2015,2019],"xaxis":"x","y":[84.2901077271,87.8914413452],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Uganda<br>Year=%{x}<br>Literacy Rate Youth Total=%{y}<extra></extra>","legendgroup":"Uganda","line":{"color":"#8C564B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Uganda","orientation":"v","showlegend":true,"x":[2012,2018],"xaxis":"x","y":[83.6588821411,89.3963088989],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":false,"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Year"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Literacy Rate Youth Total"}},"legend":{"title":{"text":"Country Name"},"tracegroupgap":0},"title":{"text":"Literacy rate, youth total(% of people ages 15-24)"},"height":600,"showlegend":true},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('6fae3b76-fe9d-45c9-aee5-726aba816fff');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
df_gov_exp = df.query("indicator == 'SE.XPD.TOTL.GB.ZS'").query("Year == 2012")
fig = px.bar(
    df_gov_exp, 
    x="Country Name", 
    labels={"value":"2012 Government expenditure on education"},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5],
    title="Government expenditure on education, total(% of government expenditure)"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="26abd19a-c97b-4cfa-a59d-7bc171561c5d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26abd19a-c97b-4cfa-a59d-7bc171561c5d")) {                    Plotly.newPlot(                        "26abd19a-c97b-4cfa-a59d-7bc171561c5d",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2012 Government expenditure on education=%{y}<extra></extra>","legendgroup":"Burkina Faso","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Burkina Faso","offsetgroup":"Burkina Faso","orientation":"v","showlegend":true,"textposition":"auto","x":["Burkina Faso"],"xaxis":"x","y":[15.8953800201],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2012 Government expenditure on education=%{y}<extra></extra>","legendgroup":"Ethiopia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Ethiopia","offsetgroup":"Ethiopia","orientation":"v","showlegend":true,"textposition":"auto","x":["Ethiopia"],"xaxis":"x","y":[30.5395393372],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2012 Government expenditure on education=%{y}<extra></extra>","legendgroup":"Liberia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Liberia","offsetgroup":"Liberia","orientation":"v","showlegend":true,"textposition":"auto","x":["Liberia"],"xaxis":"x","y":[5.1843400002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2012 Government expenditure on education=%{y}<extra></extra>","legendgroup":"Madagascar","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Madagascar","offsetgroup":"Madagascar","orientation":"v","showlegend":true,"textposition":"auto","x":["Madagascar"],"xaxis":"x","y":[20.325799942],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2012 Government expenditure on education=%{y}<extra></extra>","legendgroup":"Togo","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Togo","offsetgroup":"Togo","orientation":"v","showlegend":true,"textposition":"auto","x":["Togo"],"xaxis":"x","y":[17.6804294586],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2012 Government expenditure on education=%{y}<extra></extra>","legendgroup":"Uganda","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Uganda","offsetgroup":"Uganda","orientation":"v","showlegend":true,"textposition":"auto","x":["Uganda"],"xaxis":"x","y":[11.4518995285],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921 ...

# %%
fig = px.pie(df_gov_exp, values='value', names='Country Name', title='Government expenditure on education, total(% of government expenditure)',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ba69a35c-e4a3-4dd0-a1f5-fe19f9edf21f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba69a35c-e4a3-4dd0-a1f5-fe19f9edf21f")) {                    Plotly.newPlot(                        "ba69a35c-e4a3-4dd0-a1f5-fe19f9edf21f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country Name=%{label}<br>value=%{value}<extra></extra>","labels":["Burkina Faso","Ethiopia","Liberia","Madagascar","Togo","Uganda"],"legendgroup":"","name":"","showlegend":true,"values":[15.8953800201,30.5395393372,5.1843400002,20.325799942,17.6804294586,11.4518995285],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewid ...

# %%
df_sch_age = df.query("Year == 2012").query("indicator == 'SP.SEC.TOTL.IN'")

# %%
fig = px.bar(
    df_sch_age, 
    x="Country Name", 
    labels={"value":"School age population, secondary education, both sexes", "Country Name":""},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0caea87e-4546-4860-9949-d4e9a6448d63" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0caea87e-4546-4860-9949-d4e9a6448d63")) {                    Plotly.newPlot(                        "0caea87e-4546-4860-9949-d4e9a6448d63",                        [],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"line":{"color":"#283442"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"o ...
