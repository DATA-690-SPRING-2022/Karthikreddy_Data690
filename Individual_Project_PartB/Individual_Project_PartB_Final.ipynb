# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikreddy2299/Karthikreddy_Data690/blob/main/Individual_Project_PartB/Individual_Project_PartB_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Individual Project - Part B (Final)
#
#
# Name: Karthik Reddy
#
# Date: 04/09/2022

# %% [markdown]
# ## Indicator Profile:
#
# ### Education.
#
# ### Abstract:
#
# - Education means studying in order to obtain a deeper knowledge and understanding of a variety of subjects to be applied to daily life. Education is not limited to just knowledge from books, but can also be obtained through practical experiences outside of the classroom.
# - In order for the entire world to really become equal, it needs to start with education. If everyone was provided with the same opportunities to education, then there would be less gaps between social classes.
# - More than 260 million children worldwide are out of school, yet more than half of those in education are not learning, the "World Bank has warned".
# - In today’s society, having an education is considered a vital part of being accepted by those around you. Having an education is believed to make you a useful part of society, and can make you feel like a contributing member as well.
#
# ### Global education facts:
#
# - In 39 out of 99 countries, fewer than 50% of the poorest children have completed primary school. In some countries like South Sudan, that figure is as low as 7%.
# - More than 50% of young people in 58 out of 133 countries have not completed upper secondary school. In Niger, only 2% of its young people have completed this education.
# - In 35 out of 75 countries, at least 25% of the poorest young women are illiterate.
# - In 30 countries, fewer than 90 females for every 100 males complete lower-secondary school.
#
# ## Indicator Topics:
# - Population ages 15-64(% of total population).
# - Literacy rate, youth total(% of people ages 15-24).
# - Government expenditure on education, total(% of government expenditure).
# - Unemployment, total(% of total labor force).
# - Population, ages 15-24, total.
# - Coverage: Finished primary school.
#
# **Countries:**
# - Burkina Faso.
# - Ethiopia.
# - Liberia.
# - Madagascar.
# - Uganda.
# - Central African Republic.
# - Togo.
#
# **Time Plot Years:**
# - 2012 - 2020.

# %%
import pandas as pd
import plotly
import plotly.express as px

DATA = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/Karthikreddy_Data690/main/Individual_Project_PartB/wdi_data.csv"
DATA = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/Karthikreddy_Data690/main/Individual_Project_PartB/wdi_data%20(1).csv"
DATA = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/Karthikreddy_Data690/main/Individual_Project_PartB/wdi_data%20(2).csv"
DATA = "https://raw.githubusercontent.com/Karthikreddy2299/Karthikreddy_Data690/main/Individual_Project_PartB/wdx_long%20(5).csv"
DATA = "https://raw.githubusercontent.com/Karthikreddy2299/Karthikreddy_Data690/main/Individual_Project_PartB/wdx_long%20(6).csv"
DATA = "https://raw.githubusercontent.com/Karthikreddy2299/Karthikreddy_Data690/main/Individual_Project_PartB/wdx_long%20(7).csv"
DATA = "https://raw.githubusercontent.com/Karthikreddy2299/Karthikreddy_Data690/main/Individual_Project_PartB/wdx_long%20(8).csv"
DATA = "https://raw.githubusercontent.com/Karthikreddy2299/Karthikreddy_Data690/main/Individual_Project_PartB/wdx_long%20(9).csv"
DATA = "https://raw.githubusercontent.com/Karthikreddy2299/Karthikreddy_Data690/main/Individual_Project_PartB/wdx_long%20(10).csv"

# %%
df = pd.read_csv(DATA)

df.sample(15)
# Out:
#       Unnamed: 0  Year         value          indicator Country Code  \
# 937          937  2013  2.866034e+01  SE.XPD.TOTL.GB.ZS          ZWE
# 348          348  2018  1.205605e+06     SP.SEC.TOTL.IN          SLE
# 67            67  2016  7.904750e+05     SP.SEC.TOTL.IN          CAF
# 708          708  2013  2.702110e+01  SE.XPD.TOTL.GB.ZS          ETH
# 125          125  2020  1.469120e+05     SP.SEC.TOTL.IN          GNQ
# 508          508  2012  5.313892e+06  SP.POP.1524.TO.UN          GHA
# 1303        1303  2012  1.219800e+01     SL.UEM.TOTL.ZS          SSD
# 1139        1139  2019  6.036000e+00     SL.UEM.TOTL.ZS          GNB
# 1081        1081  2015  2.332900e+01     SL.UEM.TOTL.ZS          SWZ
# 417          417  2015  1.844834e+06     SP.SEC.TOTL.IN          ZMB
# 205          205  2019  7.506670e+06     SP.SEC.TOTL.IN          KEN
# 402          402  2018  1.214479e+06     SP.SEC.TOTL.IN          TGO
# 1207        1207  2015  7.410000e+00     SL.UEM.TOTL.ZS          MUS
# ...

# %%
df['Country Name'].unique()
# Out:
# array(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', "Cote d'Ivoire",
#        'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon',
#        'Gambia, The', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya',
#        'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania',
#        'Mauritius', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania',
#        'Togo', 'Uganda', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
df['Country Code'].unique()
# Out:
# array(['AGO', 'BEN', 'BWA', 'BFA', 'BDI', 'CPV', 'CMR', 'CAF', 'TCD',
#        'COM', 'COD', 'COG', 'CIV', 'GNQ', 'ERI', 'SWZ', 'ETH', 'GAB',
#        'GMB', 'GHA', 'GIN', 'GNB', 'KEN', 'LSO', 'LBR', 'MDG', 'MWI',
#        'MLI', 'MRT', 'MUS', 'MOZ', 'NAM', 'NER', 'NGA', 'RWA', 'STP',
#        'SEN', 'SYC', 'SLE', 'SOM', 'ZAF', 'SSD', 'SDN', 'TZA', 'TGO',
#        'UGA', 'ZMB', 'ZWE'], dtype=object)

# %%
df.head(20)
# Out:
#     Unnamed: 0  Year      value       indicator Country Code Country Name  \
# 0            0  2012  3456723.0  SP.SEC.TOTL.IN          AGO       Angola
# 1            1  2013  3582561.0  SP.SEC.TOTL.IN          AGO       Angola
# 2            2  2014  3717737.0  SP.SEC.TOTL.IN          AGO       Angola
# 3            3  2015  3862337.0  SP.SEC.TOTL.IN          AGO       Angola
# 4            4  2016  4014388.0  SP.SEC.TOTL.IN          AGO       Angola
# 5            5  2017  4177751.0  SP.SEC.TOTL.IN          AGO       Angola
# 6            6  2018  4350601.0  SP.SEC.TOTL.IN          AGO       Angola
# 7            7  2019  4532748.0  SP.SEC.TOTL.IN          AGO       Angola
# 8            8  2020  4722664.0  SP.SEC.TOTL.IN          AGO       Angola
# 9            9  2012  1512291.0  SP.SEC.TOTL.IN          BEN        Benin
# 10          10  2013  1552721.0  SP.SEC.TOTL.IN          BEN        Benin
# 11          11  2014  1594627.0  SP.SEC.TOTL.IN          BEN        Benin
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0  Year      value          indicator Country Code  \
# 1857        1857  2018  17.012430  SE.XPD.TOTL.GB.ZS          ZMB
# 1858        1858  2019  15.291870  SE.XPD.TOTL.GB.ZS          ZMB
# 1859        1859  2020  12.378020  SE.XPD.TOTL.GB.ZS          ZMB
# 1860        1860  2012  29.751089  SE.XPD.TOTL.GB.ZS          ZWE
# 1861        1861  2013  28.660339  SE.XPD.TOTL.GB.ZS          ZWE
# 1862        1862  2014  30.015150  SE.XPD.TOTL.GB.ZS          ZWE
# 1863        1863  2015  29.470831  SE.XPD.TOTL.GB.ZS          ZWE
# 1864        1864  2016  23.527081  SE.XPD.TOTL.GB.ZS          ZWE
# 1865        1865  2017  20.874201  SE.XPD.TOTL.GB.ZS          ZWE
# 1866        1866  2018  19.039841  SE.XPD.TOTL.GB.ZS          ZWE
#
#      Country Name               Region         Income Group Lending Type
# 1857       Zambia  Sub-Saharan Africa   Lower middle income          IDA
# 1858       Zambia  Sub-Saharan Africa   Lower middle income          IDA
# ...

# %%
df_2019_pop_age = df.query("Year == 2012").query("indicator == 'SP.POP.1564.TO.ZS'")
df_2019_pop_age
# Out:
#       Unnamed: 0  Year      value          indicator Country Code  \
# 933          933  2012  50.467978  SP.POP.1564.TO.ZS          AGO
# 942          942  2012  53.160280  SP.POP.1564.TO.ZS          BEN
# 951          951  2012  61.603555  SP.POP.1564.TO.ZS          BWA
# 960          960  2012  51.467297  SP.POP.1564.TO.ZS          BFA
# 969          969  2012  52.644390  SP.POP.1564.TO.ZS          BDI
# 978          978  2012  64.025651  SP.POP.1564.TO.ZS          CPV
# 987          987  2012  53.615964  SP.POP.1564.TO.ZS          CMR
# 996          996  2012  52.299401  SP.POP.1564.TO.ZS          CAF
# 1005        1005  2012  48.971188  SP.POP.1564.TO.ZS          TCD
# 1014        1014  2012  56.371094  SP.POP.1564.TO.ZS          COM
# 1023        1023  2012  50.644208  SP.POP.1564.TO.ZS          COD
# 1032        1032  2012  55.456710  SP.POP.1564.TO.ZS          COG
# 1041        1041  2012  53.924549  SP.POP.1564.TO.ZS          CIV
# ...

# %%
df_uga = [df_2019_pop_age['Country Code']== 'UGA']
df_uga
# Out:
# [933     False
#  942     False
#  951     False
#  960     False
#  969     False
#  978     False
#  987     False
#  996     False
#  1005    False
#  1014    False
#  1023    False
#  1032    False
#  1041    False
#  1050    False
#  1059    False
#  1068    False
#  1077    False
#  1086    False
#  1095    False
#  1104    False
#  1113    False
#  1122    False
#  1131    False
#  1140    False
#  1149    False
#  1158    False
#  1167    False
#  1176    False
#  1185    False
#  1194    False
#  1203    False
#  1212    False
#  1221    False
#  1230    False
#  1239    False
#  1248    False
#  1257    False
#  1266    False
#  1275    False
#  1284    False
#  1293    False
#  1302    False
#  1311    False
#  1320    False
#  1329     True
#  1338    False
#  1347    False
#  Name: Country Code, dtype: bool]

# %%
df_caf = df_2019_pop_age[df_2019_pop_age['Country Code']== 'CAF']
df_caf
# Out:
#      Unnamed: 0  Year      value          indicator Country Code  \
# 996         996  2012  52.299401  SP.POP.1564.TO.ZS          CAF
#
#                  Country Name               Region Income Group Lending Type
# 996  Central African Republic  Sub-Saharan Africa    Low income          IDA

# %%
fig = px.bar(
   df_2019_pop_age, 
    x="Country Name", 
    labels={"value":"2012 Bar Plot of all countries Population Ages", "Country Name":""},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pop_age = df.query("Year == 2012").query("indicator == 'SP.POP.1564.TO.ZS'")
df_pop_age
# Out:
#      Unnamed: 0  Year      value          indicator Country Code  \
# 149         149  2012  51.467297  SP.POP.1564.TO.ZS          BFA
# 158         158  2012  52.299401  SP.POP.1564.TO.ZS          CAF
# 167         167  2012  52.770910  SP.POP.1564.TO.ZS          ETH
# 176         176  2012  53.884061  SP.POP.1564.TO.ZS          LBR
# 185         185  2012  54.352105  SP.POP.1564.TO.ZS          MDG
# 194         194  2012  54.569844  SP.POP.1564.TO.ZS          TGO
# 203         203  2012  49.388649  SP.POP.1564.TO.ZS          UGA
#
#                  Country Name               Region Income Group Lending Type
# 149              Burkina Faso  Sub-Saharan Africa    Low income          IDA
# 158  Central African Republic  Sub-Saharan Africa    Low income          IDA
# 167                  Ethiopia  Sub-Saharan Africa    Low income          IDA
# 176                   Liberia  Sub-Saharan Africa    Low income          IDA
# ...

# %%
fig = px.bar(
   df_pop_age, 
    x="Country Name", 
    labels={"value":"2012 Bar Plot of selected countries Population Ages", "Country Name":""},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_lit_rate = df.query("indicator == 'SE.ADT.1524.LT.ZS'")

# %%
df_lit_rate = df_lit_rate[df_lit_rate["Country Code"].isin(["BFA","CAF","ETH","LBR","MGD","TGO","UGA"])]

fig = px.line(
    df_lit_rate, 
    x="Year", 
    labels={"value":"Literacy Rate %"},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5],
    title="Literacy rate, youth total(% of people ages 15-24)."

)


fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_gov_exp = df.query("indicator == 'SE.XPD.TOTL.GB.ZS'").query("Year == 2012")
fig = px.pie(df_gov_exp, values='value', names='Country Name', title='Government expenditure on education, total(% of government expenditure)',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(
    df_gov_exp, 
    x="Country Name", 
    labels={"value":"2012 Government expenditure on education"},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5],
    title="Government expenditure on education, total(% of government expenditure)"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_unemp_tot = df.query("indicator == 'SL.UEM.TOTL.ZS'")

# %%
df_unemp_tot = df_unemp_tot[df_unemp_tot["Country Code"].isin(["BFA","CAF", "ETH", "LBR","MDG","TGO","UGA"])]

fig = px.line(
    df_unemp_tot, 
    x="Year", 
    labels={"value":"Unemployment Total %"},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5],
    title="Unemployment, total(% of total labor force)."

)


fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pop_age = df.query("indicator == 'SP.POP.1564.TO.ZS'")
df_pop_age = df_pop_age[df_pop_age["Country Code"].isin(["BFA","CAF", "ETH", "LBR","MDG","TGO","UGA"])]
i2 = df_pop_age["value"]
i5 = df_pop_age["Year"]

df_unemp_tot = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_unemp_tot = df_unemp_tot[df_unemp_tot["Country Code"].isin(["BFA","CAF", "ETH", "LBR","MDG","TGO","UGA"])]
i3 = df_unemp_tot["value"]

df2 = pd.DataFrame({ 'Year': i5.values, 'POP': i3.values, 'UNEMP': i2.values})

# %%
fig = px.scatter(df2, x="UNEMP", y="POP",labels={"UNEMP":"Unemployment Total", "POP":"Population ages"},
    height=800,
    trendline="lowess",
    text="Year",
    title="Umemployment vs Total Population",
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom center")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_sch_age = df.query("Year == 2012").query("indicator == 'SP.SEC.TOTL.IN'")
df_sch_age
# Out:
#      Unnamed: 0  Year       value       indicator Country Code  \
# 0             0  2012   3456723.0  SP.SEC.TOTL.IN          AGO
# 9             9  2012   1512291.0  SP.SEC.TOTL.IN          BEN
# 18           18  2012    205915.0  SP.SEC.TOTL.IN          BWA
# 27           27  2012   2608008.0  SP.SEC.TOTL.IN          BFA
# 36           36  2012   1463007.0  SP.SEC.TOTL.IN          BDI
# 45           45  2012     66595.0  SP.SEC.TOTL.IN          CPV
# 54           54  2012   3321430.0  SP.SEC.TOTL.IN          CMR
# 63           63  2012    723858.0  SP.SEC.TOTL.IN          CAF
# 72           72  2012   2052023.0  SP.SEC.TOTL.IN          TCD
# 81           81  2012    111097.0  SP.SEC.TOTL.IN          COM
# 90           90  2012   9008510.0  SP.SEC.TOTL.IN          COD
# 99           99  2012    645050.0  SP.SEC.TOTL.IN          COG
# 108         108  2012   3453683.0  SP.SEC.TOTL.IN          CIV
# 117         117  2012    106940.0  SP.SEC.TOTL.IN          GNQ
# ...

# %%
fig = px.bar(
   df_sch_age, 
    x="Country Name", 
    labels={"value":"2012 Bar Plot of School age population, secondary education, both sexes", "Country Name":""},
    y="value",
    color="Country Name",
    height=600,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
